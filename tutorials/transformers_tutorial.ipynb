# %% [markdown]
# # Developing an Transformer Network using ManufacturingNet
# ###### To know more about the manufacturingnet please visit: http://manufacturingnet.io/

# %% [markdown]
# ## Let us import the package and other required libraries

# %%
import ManufacturingNet
import numpy as np

# %% [markdown]
# ##### Let us download the dataset for our Transformer network. The data is already processed and made ready for training

# %%
from ManufacturingNet import datasets

# %%
datasets.MotorTempData()
# Out:
# ---------------------------------------------------------------------------
# BadZipFile                                Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 datasets.MotorTempData()
#
# File ~\AppData\Roaming\Python\Python313\site-packages\ManufacturingNet\datasets\datasets.py:62, in MotorTempData()
#      59 destination = 'MotorTempData.zip'
#      61 download_file_from_google_drive(data_id, destination)
# ---> 62 extract_files(destination)
#      63 remove_zip(destination)
#
# File ~\AppData\Roaming\Python\Python313\site-packages\ManufacturingNet\datasets\datasets.py:36, in extract_files(name)
#      34 def extract_files(name):
# ---> 36     Zip = ZipFile(name)
#      37     Zip.extractall()
#
# File c:\Python313\Lib\zipfile\__init__.py:1385, in ZipFile.__init__(self, file, mode, compression, allowZip64, compresslevel, strict_timestamps, metadata_encoding)
#    1383 try:
#    1384     if mode == 'r':
# -> 1385         self._RealGetContents()
#    1386     elif mode in ('w', 'x'):
#    1387         # set the modified flag so central directory gets written
#    1388         # even if no files are added to the archive
#    1389         self._didModify = True
#
# File c:\Python313\Lib\zipfile\__init__.py:1452, in ZipFile._RealGetContents(self)
#    1450     raise BadZipFile("File is not a zip file")
#    1451 if not endrec:
# -> 1452     raise BadZipFile("File is not a zip file")
#    1453 if self.debug > 1:
#    1454     print(endrec)
#
# BadZipFile: File is not a zip file

# %% [markdown]
# ###### The data is downloaded in the root directoty. Ready to use!

# %% [markdown]
# The Paderborn Motor temperature dataset has close to 1 million data points. Its a regression problem. Based on the given values of other parameters such as coolant temperature, ambient temperature, load, current, voltage, etc., we will try to predict the rotor temperature.

# %% [markdown]
# ##### Let us load the data

# %%
x = np.load('Motor_temperature/input data.npy', allow_pickle = True)
y = np.load('Motor_temperature/labels.npy', allow_pickle = True)

# %% [markdown]
# ##### For demonstration purpose, we will use just 1000 points

# %%
x = x[0:50000]
y = y[0:50000].reshape(-1, 1)
x.shape, y.shape
# Out:
# ((50000, 60, 11), (50000, 1))

# %% [markdown]
# ## We are all set to make our own Transformer network without actually coding it up!

# %%
from ManufacturingNet.models import Transformer

# %%
model = Transformer(x, y)

# %% [markdown]
# See! We just trained an Transformer Network using ManufacturingNet package without actually writing the code. Transformer's are especially useful when dealing with time series data and have many applications.
#
# The input data here has 11 features so we use 11 neurons in the input layer. As the problem was of regression nature, we added just one neuron in the ouput layer. However, for classification, please change the number of neurons according to your problem.
#
# The model summary, training accuracy, validation accuracy, r2-score, confusion matrix (in case of classification problem), Loss  vs epoch graph are also provided by the package.
#
# Also, since we just used 1000 points, the results are not very good.
